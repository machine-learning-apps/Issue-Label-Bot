# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" # so the IDs match nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"] = "0" # "0, 1" for multiple

# %% [markdown]
# # Load the data

# %%
! ls
# Out:
# 1_Download_and_Preprocess.ipynb
# 2_Build_Model.ipynb
# Demo.ipynb
# IssueLabeler.epoch01-val0.84455.hdf5
# IssueLabeler.epoch01-val0.86108.hdf5
# IssueLabeler.epoch02-val0.84564.hdf5
# IssueLabeler.epoch03-val0.83802.hdf5
# IssueLabeler.log
# IssueLabeler_nbow_.epoch01-val0.89053.hdf5
# IssueLabeler_nbow_.epoch01-val0.89168.hdf5
# IssueLabeler_nbow_.epoch02-val0.87182.hdf5
# IssueLabeler_nbow_.epoch02-val0.88291.hdf5
# IssueLabeler_nbow_.epoch03-val0.87658.hdf5
# IssueLabeler_nbow_.epoch04-val0.87004.hdf5
# IssueLabeler_nbow_.epoch05-val0.86841.hdf5
# IssueLabeler_nbow_.log
# IssueLabeler_nobd.epoch01-val0.85034.hdf5
# IssueLabeler_nobd.epoch02-val0.83598.hdf5
# IssueLabeler_nobd.epoch03-val0.83539.hdf5
# IssueLabeler_nobd.log
# IssueLabeler_nobd_v2.epoch01-val0.48195.hdf5
# IssueLabeler_nobd_v2.epoch02-val0.46649.hdf5
# IssueLabeler_nobd_v2.log
# IssueLabeler_nobd_v3.epoch01-val0.48515.hdf5
# IssueLabeler_nobd_v3.epoch02-val0.47624.hdf5
# IssueLabeler_nobd_v3.epoch03-val0.47322.hdf5
# IssueLabeler_nobd_v3.epoch04-val0.47142.hdf5
# IssueLabeler_nobd_v3.log
# __pycache__
# body_pp.dpkl
# core
# labeled_issues_df.pkl
# mlapp.py
# seq2seq_utils.py
# test_body_vecs.npy
# test_labels.npy
# test_title_vecs.npy
# testdf.pkl
# title_pp.dpkl
# train_body_vecs.npy
# train_labels.npy
# train_title_vecs.npy
# traindf.pkl
# transfer_learning_best_model.hdf5

# %%
import numpy as np
import dill as dpickle

def load_pickle(fname):
    "load file pickled with dill."
    with open(fname, 'rb') as f:
        pp = dpickle.load(f)
    return pp

# %%
#load the text pre-processors
title_pp = load_pickle('title_pp.dpkl')
body_pp = load_pickle('body_pp.dpkl')

#load the training data and labels
train_body_vecs = np.load('train_body_vecs.npy')
train_title_vecs = np.load('train_title_vecs.npy')
train_labels = np.load('train_labels.npy')

#load the test data and labels
test_body_vecs = np.load('test_body_vecs.npy')
test_title_vecs = np.load('test_title_vecs.npy')
test_labels = np.load('test_labels.npy')
# Out:
# Using TensorFlow backend.

# %%
# decided to get rid of the last class "other"
train_mask = train_labels != 3
test_mask = test_labels != 3

train_body_vecs = train_body_vecs[train_mask]
train_title_vecs = train_title_vecs[train_mask]
train_labels = train_labels[train_mask]

test_body_vecs = test_body_vecs[test_mask]
test_title_vecs = test_title_vecs[test_mask]
test_labels = test_labels[test_mask]

# %% [markdown]
# ### Build Model Architecture

# %%
import tensorflow as tf
from tensorflow.keras.utils import multi_gpu_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Embedding, Conv1D, Bidirectional, BatchNormalization, Dot, Flatten, Concatenate
from tensorflow.keras.optimizers import Nadam

# %%
tf.__version__
# Out:
# '1.12.0'

# %%
issue_body_doc_length = train_body_vecs.shape[1]
issue_title_doc_length = train_title_vecs.shape[1]

body_vocab_size = body_pp.n_tokens
title_vocab_size = title_pp.n_tokens

body_emb_size = 400
title_emb_size = 300

num_classes = len(set(train_labels))

# %%
body_input = Input(shape=(issue_body_doc_length,), name='Body-Input')
title_input = Input(shape=(issue_title_doc_length,), name='Title-Input')

b_i = Embedding(body_vocab_size, body_emb_size, name='Body-Embedding', mask_zero=False)(body_input)
b_t = Embedding(title_vocab_size, title_emb_size, name='Title-Embedding', mask_zero=False)(title_input)

b_i = BatchNormalization()(b_i)
b_i = Bidirectional(GRU(300, name='Body-Encoder'))(b_i)

b_t = BatchNormalization()(b_t)
b_t = GRU(300, name='Title-Encoder')(b_t)

b = Concatenate(name='Concat')([b_i, b_t])
#b = Dense(100, activation='relu', name='Dense1')(b_concat)
b = BatchNormalization()(b)
out = Dense(num_classes, activation='softmax')(b)

model = Model([body_input, title_input], out)
parallel_model = multi_gpu_model(model, gpus=4)
parallel_model.compile(optimizer=Nadam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
parallel_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Body-Input (InputLayer)         (None, 140)          0
# __________________________________________________________________________________________________
# Title-Input (InputLayer)        (None, 10)           0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 140)          0           Body-Input[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 10)           0           Title-Input[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 140)          0           Body-Input[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 10)           0           Title-Input[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 140)          0           Body-Input[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 10)           0           Title-Input[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 140)          0           Body-Input[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 10)           0           Title-Input[0][0]
# __________________________________________________________________________________________________
# model (Model)                   (None, 4)            6513404     lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# dense (Concatenate)             (None, 4)            0           model[1][0]
#                                                                  model[2][0]
#                                                                  model[3][0]
#                                                                  model[4][0]
# ==================================================================================================
# Total params: 6,513,404
# Trainable params: 6,510,204
# Non-trainable params: 3,200
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint

script_name_base = 'IssueLabeler'
csv_logger = CSVLogger('{:}.log'.format(script_name_base))
model_checkpoint = ModelCheckpoint('{:}.epoch{{epoch:02d}}-val{{val_loss:.5f}}.hdf5'.format(script_name_base),
                                   save_best_only=True)

batch_size = 6400
epochs = 10
history = parallel_model.fit(x=[train_body_vecs, train_title_vecs], 
                             y=np.expand_dims(train_labels, -1),
                             batch_size=batch_size,
                             epochs=epochs,
                             validation_split=0.10, 
                             callbacks=[csv_logger, model_checkpoint])
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 4486247 samples, validate on 498472 samples
# Epoch 1/10
# 4486247/4486247 [==============================] - 1074s 239us/step - loss: 0.9147 - acc: 0.5811 - val_loss: 0.8611 - val_acc: 0.6023
# Epoch 2/10
# 4486247/4486247 [==============================] - 1061s 236us/step - loss: 0.8317 - acc: 0.6207 - val_loss: 0.8456 - val_acc: 0.6100
# Epoch 3/10
# 4486247/4486247 [==============================] - 1062s 237us/step - loss: 0.7987 - acc: 0.6398 - val_loss: 0.8380 - val_acc: 0.6172
# Epoch 4/10
# 4486247/4486247 [==============================] - 1062s 237us/step - loss: 0.7657 - acc: 0.6587 - val_loss: 0.8441 - val_acc: 0.6164
# Epoch 5/10
# 4486247/4486247 [==============================] - 1061s 237us/step - loss: 0.7277 - acc: 0.6800 - val_loss: 0.8636 - val_acc: 0.6109
# Epoch 6/10
# 4486247/4486247 [==============================] - 1060s 236us/step - loss: 0.6841 - acc: 0.7037 - val_loss: 0.8896 - val_acc: 0.6062
# Epoch 7/10
# 4486247/4486247 [==============================] - 1060s 236us/step - loss: 0.6354 - acc: 0.7291 - val_loss: 0.9307 - val_acc: 0.6010
# Epoch 8/10
# 4486247/4486247 [==============================] - 1062s 237us/step - loss: 0.5847 - acc: 0.7545 - val_loss: 0.9823 - val_acc: 0.5933
# Epoch 9/10
# 4486247/4486247 [==============================] - 1062s 237us/step - loss: 0.5344 - acc: 0.7788 - val_loss: 1.0410 - val_acc: 0.5903
# Epoch 10/10
# 4486247/4486247 [==============================] - 1060s 236us/step - loss: 0.4864 - acc: 0.8014 - val_loss: 1.1159 - val_acc: 0.5840

# %% [markdown]
# ### Try another approach: Nueral BoW

# %%
body_input2 = Input(shape=(issue_body_doc_length,), name='Body-Input')
title_input2 = Input(shape=(issue_title_doc_length,), name='Title-Input')

b_i2 = Embedding(body_vocab_size, body_emb_size//2, name='Body-Embedding', mask_zero=False)(body_input2)
b_t2 = Embedding(title_vocab_size, title_emb_size//2, name='Title-Embedding', mask_zero=False)(title_input2)

token_weights_i = Dense(units=1, activation='sigmoid', use_bias=False)(b_i2)
token_weights_t = Dense(units=1, activation='sigmoid', use_bias=False)(b_t2)

i_emb = Dot(axes=1, normalize=True, name='body_encoding')([b_i2, token_weights_i])
i = Flatten()(i_emb)
t_emb = Dot(axes=1, normalize=True, name='title_encoding')([b_t2, token_weights_t])
t = Flatten()(t_emb)

b = Concatenate(name='Concat')([i, t])
b = Dense(100, activation='relu', name='Dense1')(b)
b = BatchNormalization()(b)
out = Dense(num_classes, activation='softmax')(b)

model2 = Model([body_input2, title_input2], out)
parallel_model_nbow = multi_gpu_model(model2, gpus=4)
parallel_model_nbow.compile(optimizer=Nadam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model2.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Body-Input (InputLayer)         (None, 140)          0
# __________________________________________________________________________________________________
# Title-Input (InputLayer)        (None, 10)           0
# __________________________________________________________________________________________________
# Body-Embedding (Embedding)      (None, 140, 200)     1600200     Body-Input[0][0]
# __________________________________________________________________________________________________
# Title-Embedding (Embedding)     (None, 10, 150)      750150      Title-Input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 140, 1)       200         Body-Embedding[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10, 1)        150         Title-Embedding[0][0]
# __________________________________________________________________________________________________
# body_encoding (Dot)             (None, 200, 1)       0           Body-Embedding[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# title_encoding (Dot)            (None, 150, 1)       0           Title-Embedding[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 200)          0           body_encoding[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 150)          0           title_encoding[0][0]
# __________________________________________________________________________________________________
# Concat (Concatenate)            (None, 350)          0           flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 100)          35100       Concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100)          400         Dense1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            404         batch_normalization_1[0][0]
# ==================================================================================================
# Total params: 2,386,604
# Trainable params: 2,386,404
# Non-trainable params: 200
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint

script_name_base = 'IssueLabeler_nbow_'
csv_logger = CSVLogger('{:}.log'.format(script_name_base))
model_checkpoint = ModelCheckpoint('{:}.epoch{{epoch:02d}}-val{{val_loss:.5f}}.hdf5'.format(script_name_base),
                                   save_best_only=True)

batch_size = 20000
epochs = 10
history = parallel_model_nbow.fit(x=[train_body_vecs, train_title_vecs], 
                             y=np.expand_dims(train_labels, -1),
                             batch_size=batch_size,
                             epochs=epochs,
                             validation_split=0.10, 
                             callbacks=[csv_logger, model_checkpoint])
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 4486247 samples, validate on 498472 samples
# Epoch 1/10
# 4486247/4486247 [==============================] - 51s 11us/step - loss: 0.9772 - acc: 0.5655 - val_loss: 0.8917 - val_acc: 0.5899
# Epoch 2/10
# 4486247/4486247 [==============================] - 48s 11us/step - loss: 0.8704 - acc: 0.6014 - val_loss: 0.8829 - val_acc: 0.5938
# Epoch 3/10
# 4486247/4486247 [==============================] - 47s 11us/step - loss: 0.8521 - acc: 0.6115 - val_loss: 0.8766 - val_acc: 0.5951
# Epoch 4/10
# 4486247/4486247 [==============================] - 48s 11us/step - loss: 0.8530 - acc: 0.6122 - val_loss: 0.8700 - val_acc: 0.6013
# Epoch 5/10
# 4486247/4486247 [==============================] - 48s 11us/step - loss: 0.8273 - acc: 0.6262 - val_loss: 0.8684 - val_acc: 0.6026
# Epoch 6/10
# 4486247/4486247 [==============================] - 47s 11us/step - loss: 0.8100 - acc: 0.6365 - val_loss: 0.8790 - val_acc: 0.5985
# Epoch 7/10
# 4486247/4486247 [==============================] - 47s 10us/step - loss: 0.7941 - acc: 0.6456 - val_loss: 0.8783 - val_acc: 0.5998
# Epoch 8/10
# 4486247/4486247 [==============================] - 47s 10us/step - loss: 0.7784 - acc: 0.6546 - val_loss: 0.8998 - val_acc: 0.5895
# Epoch 9/10
# 4486247/4486247 [==============================] - 47s 11us/step - loss: 0.7637 - acc: 0.6631 - val_loss: 0.8966 - val_acc: 0.5948
# Epoch 10/10
# 4486247/4486247 [==============================] - 47s 11us/step - loss: 0.7494 - acc: 0.6711 - val_loss: 0.9279 - val_acc: 0.5876

# %% [markdown]
# ## Without Bi-Directional

# %%
body_emb_size
# Out:
# 400

# %%
body_input = Input(shape=(issue_body_doc_length,), name='Body-Input')
title_input = Input(shape=(issue_title_doc_length,), name='Title-Input')

b_i = Embedding(body_vocab_size, 100, name='Body-Embedding', mask_zero=False)(body_input)
b_t = Embedding(title_vocab_size, 100, name='Title-Embedding', mask_zero=False)(title_input)

b_i = BatchNormalization()(b_i)
b_i = GRU(200, name='Body-Encoder')(b_i)

b_t = BatchNormalization()(b_t)
b_t = GRU(150, name='Title-Encoder')(b_t)

b = Concatenate(name='Concat')([b_i, b_t])
#b = Dense(100, activation='relu', name='Dense1')(b_concat)
b = BatchNormalization()(b)
out = Dense(num_classes, activation='softmax')(b)

model = Model([body_input, title_input], out)
parallel_model = multi_gpu_model(model, gpus=4)
parallel_model.compile(optimizer=Nadam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Body-Input (InputLayer)         (None, 140)          0
# __________________________________________________________________________________________________
# Title-Input (InputLayer)        (None, 10)           0
# __________________________________________________________________________________________________
# Body-Embedding (Embedding)      (None, 140, 100)     800100      Body-Input[0][0]
# __________________________________________________________________________________________________
# Title-Embedding (Embedding)     (None, 10, 100)      500100      Title-Input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 140, 100)     400         Body-Embedding[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 10, 100)      400         Title-Embedding[0][0]
# __________________________________________________________________________________________________
# Body-Encoder (GRU)              (None, 200)          180600      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# Title-Encoder (GRU)             (None, 150)          112950      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# Concat (Concatenate)            (None, 350)          0           Body-Encoder[0][0]
#                                                                  Title-Encoder[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 350)          1400        Concat[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3)            1053        batch_normalization_14[0][0]
# ==================================================================================================
# Total params: 1,597,003
# Trainable params: 1,595,903
# Non-trainable params: 1,100
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint

script_name_base = 'IssueLabeler_nobd_v3'
csv_logger = CSVLogger('{:}.log'.format(script_name_base))
model_checkpoint = ModelCheckpoint('{:}.epoch{{epoch:02d}}-val{{val_loss:.5f}}.hdf5'.format(script_name_base),
                                   save_best_only=True)

batch_size = 10000
epochs = 10
history = parallel_model.fit(x=[train_body_vecs, train_title_vecs], 
                             y=np.expand_dims(train_labels, -1),
                             batch_size=batch_size,
                             epochs=epochs,
                             validation_split=0.10, 
                             callbacks=[csv_logger, model_checkpoint])
# Out:
# Train on 2429154 samples, validate on 269907 samples
# Epoch 1/10
# 2429154/2429154 [==============================] - 194s 80us/step - loss: 0.5573 - acc: 0.7867 - val_loss: 0.4852 - val_acc: 0.8162
# Epoch 2/10
# 2429154/2429154 [==============================] - 181s 75us/step - loss: 0.4665 - acc: 0.8226 - val_loss: 0.4762 - val_acc: 0.8182
# Epoch 3/10
# 2429154/2429154 [==============================] - 181s 75us/step - loss: 0.4456 - acc: 0.8302 - val_loss: 0.4732 - val_acc: 0.8197
# Epoch 4/10
# 2429154/2429154 [==============================] - 181s 75us/step - loss: 0.4285 - acc: 0.8367 - val_loss: 0.4714 - val_acc: 0.8227
# Epoch 5/10
# 2429154/2429154 [==============================] - 180s 74us/step - loss: 0.4114 - acc: 0.8434 - val_loss: 0.4722 - val_acc: 0.8218
# Epoch 6/10
# 2429154/2429154 [==============================] - 181s 74us/step - loss: 0.3932 - acc: 0.8507 - val_loss: 0.4832 - val_acc: 0.8179
# Epoch 7/10
# 2429154/2429154 [==============================] - 181s 75us/step - loss: 0.3739 - acc: 0.8581 - val_loss: 0.4977 - val_acc: 0.8161
# Epoch 8/10
# 2429154/2429154 [==============================] - 181s 74us/step - loss: 0.3534 - acc: 0.8662 - val_loss: 0.5130 - val_acc: 0.8118
# Epoch 9/10
# 2429154/2429154 [==============================] - 181s 74us/step - loss: 0.3321 - acc: 0.8745 - val_loss: 0.5330 - val_acc: 0.8072
# Epoch 10/10
# 2429154/2429154 [==============================] - 181s 74us/step - loss: 0.3101 - acc: 0.8834 - val_loss: 0.5678 - val_acc: 0.8005

# %%
from tensorflow.keras.models import load_model
model = load_model('IssueLabeler_nobd_v3.epoch04-val0.47142.hdf5')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# # Share Vocabularies
#
# I noticed model is still overparameterized and the place where the most parameters are in the embeddings, which makes me want to try sharing the embeddings.

# %%
import pandas as pd

traindf = pd.read_pickle('traindf.pkl')
testdf = pd.read_pickle('testdf.pkl')
body_pp = load_pickle('body_pp.dpkl')

train_title_vecs = body_pp.transform_parallel(traindf[~traindf.c_other].title.tolist())
test_title_vecs = body_pp.transform_parallel(testdf[~testdf.c_other].title.tolist())
# Out:
# WARNING:root:...tokenizing data
# WARNING:root:...indexing data
# WARNING:root:...padding data
# WARNING:root:...tokenizing data
# WARNING:root:...indexing data
# WARNING:root:...padding data

# %%
#load the training data and labels
train_body_vecs = np.load('train_body_vecs.npy')
train_labels = np.load('train_labels.npy')

#load the test data and labels
test_body_vecs = np.load('test_body_vecs.npy')
test_labels = np.load('test_labels.npy')


# decided to get rid of the last class "other"
train_mask = train_labels != 3
test_mask = test_labels != 3

train_body_vecs = train_body_vecs[train_mask]
train_labels = train_labels[train_mask]

test_body_vecs = test_body_vecs[test_mask]
test_labels = test_labels[test_mask]

# %%
issue_body_doc_length = train_body_vecs.shape[1]
issue_title_doc_length = train_title_vecs.shape[1]

body_vocab_size = body_pp.n_tokens

num_classes = len(set(train_labels))

# %%
import tensorflow as tf
from tensorflow.keras.utils import multi_gpu_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Embedding, Conv1D, Bidirectional, BatchNormalization, Dot, Flatten, Concatenate
from tensorflow.keras.optimizers import Nadam

# %%
body_input = Input(shape=(issue_body_doc_length,), name='Body-Input')
title_input = Input(shape=(issue_title_doc_length,), name='Title-Input')

emb = Embedding(body_vocab_size, 100, name='Shared-Embedding', mask_zero=False)

#share embedding weights
b_i = emb(body_input)
b_t = emb(title_input)

b_i = BatchNormalization()(b_i)
b_i = GRU(200, name='Body-Encoder')(b_i)

b_t = BatchNormalization()(b_t)
b_t = GRU(150, name='Title-Encoder')(b_t)

b = Concatenate(name='Concat')([b_i, b_t])
#b = Dense(100, activation='relu', name='Dense1')(b_concat)
b = BatchNormalization()(b)
out = Dense(num_classes, activation='softmax')(b)

model = Model([body_input, title_input], out)
#

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Body-Input (InputLayer)         (None, 140)          0
# __________________________________________________________________________________________________
# Title-Input (InputLayer)        (None, 140)          0
# __________________________________________________________________________________________________
# Shared-Embedding (Embedding)    (None, 140, 100)     800100      Body-Input[0][0]
#                                                                  Title-Input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 140, 100)     400         Shared-Embedding[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 140, 100)     400         Shared-Embedding[1][0]
# __________________________________________________________________________________________________
# Body-Encoder (GRU)              (None, 200)          180600      batch_normalization[0][0]
# __________________________________________________________________________________________________
# Title-Encoder (GRU)             (None, 150)          112950      batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# Concat (Concatenate)            (None, 350)          0           Body-Encoder[0][0]
#                                                                  Title-Encoder[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 350)          1400        Concat[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            1053        batch_normalization_2[0][0]
# ==================================================================================================
# Total params: 1,096,903
# Trainable params: 1,095,803
# Non-trainable params: 1,100
# __________________________________________________________________________________________________

# %%
parallel_model = multi_gpu_model(model, gpus=4)
parallel_model.compile(optimizer=Nadam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint

script_name_base = 'IssueLabeler_sharedemb_v1'
csv_logger = CSVLogger('{:}.log'.format(script_name_base))
model_checkpoint = ModelCheckpoint('{:}.epoch{{epoch:02d}}-val{{val_loss:.5f}}.hdf5'.format(script_name_base),
                                   save_best_only=True)

batch_size = 15000
epochs = 10
history = parallel_model.fit(x=[train_body_vecs, train_title_vecs], 
                             y=np.expand_dims(train_labels, -1),
                             batch_size=batch_size,
                             epochs=epochs,
                             validation_split=0.10, 
                             callbacks=[csv_logger, model_checkpoint])
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 2429154 samples, validate on 269907 samples
# Epoch 1/10
#  975000/2429154 [===========>..................] - ETA: 2:58 - loss: 0.7028 - acc: 0.7280

# %% [markdown]
# # Confusion Matrix

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# import some data to play with
iris = datasets.load_iris()
X = iris.data
y = iris.target
class_names = iris.target_names

# Split the data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# Run classifier, using a model that is too regularized (C too low) to see
# the impact on the results
classifier = svm.SVC(kernel='linear', C=0.01)
y_pred = classifier.fit(X_train, y_train).predict(X_test)


def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax


np.set_printoptions(precision=2)

# %%
preds = model.predict(x=[test_body_vecs, test_title_vecs], batch_size=1000)

# %%
y_pred = np.argmax(preds, axis=1)

# %%
y_test = test_labels

# %%
class_names = np.array(['bug', 'feature', 'question'])

# %%
# Plot normalized confusion matrix
plot_confusion_matrix(y_test, y_pred, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
# Out:
# Normalized confusion matrix
# [[0.85 0.14 0.02]
#  [0.1  0.88 0.02]
#  [0.26 0.3  0.44]]

# %%
mistakes = y_pred != y_test

# %%
import pandas as pd
pd.set_option('max_colwidth', 1000)
df = pd.read_pickle('testdf.pkl')
df = df[~ df.c_other]
df['prediction'] = [class_names[i] for i in y_pred]

# %%
mistakes_df = df[mistakes]

# %%
mistakes_df
# Out:
#                                                                          url  \
# 327903           "https://github.com/magento/data-migration-tool/issues/529"
# 427704                        "https://github.com/Itseez/opencv/issues/6076"
# 115036                  "https://github.com/Andyjd86/ins-database/issues/15"
# 434724                          "https://github.com/zulip/zulip/issues/9396"
# 221239             "https://github.com/anisite/MESS-Asynchrone.net/issues/6"
# 148646            "https://github.com/AnisimoffNikita/web-testing/issues/20"
# 185244               "https://github.com/phpmyadmin/phpmyadmin/issues/13353"
# 547590                "https://github.com/GFDRR/osm-analytics-api/issues/14"
# 208210                         "https://github.com/DiUS/pact-jvm/issues/186"
# 87969                         "https://github.com/FlossWare/jCore/issues/11"
# 217696                 "https://github.com/allihoopa/Allihoopa-iOS/issues/3"
# 257242                          "https://github.com/SRI-CSL/sally/issues/48"
# 412095              "https://github.com/tjurczyk/arkadia-skrypty/issues/112"
# 323566             "https://github.com/MicrosoftDocs/IntuneDocs/issues/1401"
# 296801                "https://github.com/eclipse/eclipse.jdt.ls/issues/422"
# 102211        "https://github.com/NativeScript/nativescript-cli/issues/1932"
# 306101                    "https://github.com/eclipse/xtext-core/issues/169"
# 163099                          "https://github.com/pento/linkify/issues/22"
# 541134                        "https://github.com/warappa/XamlCSS/issues/38"
# 548750                  "https://github.com/poldracklab/fmriprep/issues/707"
# 379336                "https://github.com/reactor/reactor-addons/issues/151"
# 209486                       "https://github.com/intel/bmap-tools/issues/38"
# 431518       "https://github.com/savoirfairelinux/santropol-feast/issues/56"
# 456179                    "https://github.com/Islandora-CLAW/CLAW/issues/49"
# 117510                 "https://github.com/herrvigg/qtranslate-x/issues/330"
# 336778                     "https://github.com/aroemers/mount-lite/issues/9"
# 401323               "https://github.com/Azure/azure-webjobs-sdk/issues/804"
# 437198                      "https://github.com/astropy/astropy/issues/7695"
# 66574      "https://github.com/kottenator/jquery-circle-progress/issues/132"
# 334921                         "https://github.com/mgba-emu/mgba/issues/804"
# ...                                                                      ...
# 251430                  "https://github.com/mulesoft/api-console/issues/234"
# 42219                         "https://github.com/josselaer/gmpt/issues/123"
# 195325                      "https://github.com/nextcloud/server/issues/215"
# 278386      "https://github.com/silverbulleters/vanessa-behavior/issues/462"
# 264846                     "https://github.com/allinurl/goaccess/issues/438"
# 508800                       "https://github.com/Caleydo/lineage/issues/280"
# 47904   "https://github.com/atom-community/markdown-preview-plus/issues/303"
# 307034                        "https://github.com/erosson/ch2plan/issues/55"
# 451674              "https://github.com/mxstbr/react-boilerplate/issues/999"
# 424089                          "https://github.com/Tencent/wcdb/issues/426"
# 210028                     "https://github.com/fluent/fluent-bit/issues/326"
# 323022                           "https://github.com/86Box/86Box/issues/311"
# 272031                  "https://github.com/jorgenschaefer/elpy/issues/1027"
# 305158                      "https://github.com/edublancas/dstools/issues/1"
# 87839            "https://github.com/Malte311/FinanceList-Desktop/issues/53"
# 13738                 "https://github.com/nion-software/nionswift/issues/71"
# 495916                 "https://github.com/hitbtc-com/hitbtc-api/issues/128"
# 228208                    "https://github.com/Microsoft/checkedc/issues/277"
# 227098                       "https://github.com/harryrf/portfolio/issues/1"
# 594966                          "https://github.com/ntop/ntopng/issues/2254"
# 406509                     "https://github.com/envoyproxy/envoy/issues/4608"
# 510499              "https://github.com/unicef/un-partner-portal/issues/662"
# 281118                      "https://github.com/argoproj/argo-cd/issues/476"
# 527287                  "https://github.com/SamuraiWTF/samuraiwtf/issues/55"
# 513413                  "https://github.com/Kittyfisto/Tailviewer/issues/73"
# 58874               "https://github.com/camptocamp/pyramid_oereb/issues/458"
# 137109        "https://github.com/lucasmedeirosleite/EasyMapping/issues/149"
# 27640                     "https://github.com/aspnet/AspNetCore/issues/2667"
# 100841                        "https://github.com/mochajs/mocha/issues/2752"
# 423124                   "https://github.com/uracreative/identihub/issues/1"
#
#                                         repo  \
# 327903           magento/data-migration-tool
# 427704                         Itseez/opencv
# 115036                 Andyjd86/ins-database
# 434724                           zulip/zulip
# 221239           anisite/MESS-Asynchrone.net
# 148646           AnisimoffNikita/web-testing
# 185244                 phpmyadmin/phpmyadmin
# 547590               GFDRR/osm-analytics-api
# 208210                         DiUS/pact-jvm
# 87969                        FlossWare/jCore
# 217696               allihoopa/Allihoopa-iOS
# 257242                         SRI-CSL/sally
# 412095              tjurczyk/arkadia-skrypty
# 323566              MicrosoftDocs/IntuneDocs
# 296801                eclipse/eclipse.jdt.ls
# 102211         NativeScript/nativescript-cli
# 306101                    eclipse/xtext-core
# 163099                         pento/linkify
# 541134                       warappa/XamlCSS
# 548750                  poldracklab/fmriprep
# 379336                reactor/reactor-addons
# 209486                      intel/bmap-tools
# 431518      savoirfairelinux/santropol-feast
# 456179                   Islandora-CLAW/CLAW
# 117510                 herrvigg/qtranslate-x
# 336778                   aroemers/mount-lite
# 401323               Azure/azure-webjobs-sdk
# 437198                       astropy/astropy
# 66574      kottenator/jquery-circle-progress
# 334921                         mgba-emu/mgba
# ...                                      ...
# 251430                  mulesoft/api-console
# 42219                         josselaer/gmpt
# 195325                      nextcloud/server
# 278386      silverbulleters/vanessa-behavior
# 264846                     allinurl/goaccess
# 508800                       Caleydo/lineage
# 47904   atom-community/markdown-preview-plus
# 307034                       erosson/ch2plan
# 451674              mxstbr/react-boilerplate
# 424089                          Tencent/wcdb
# 210028                     fluent/fluent-bit
# 323022                           86Box/86Box
# 272031                   jorgenschaefer/elpy
# 305158                    edublancas/dstools
# 87839           Malte311/FinanceList-Desktop
# 13738                nion-software/nionswift
# 495916                 hitbtc-com/hitbtc-api
# 228208                    Microsoft/checkedc
# 227098                     harryrf/portfolio
# 594966                           ntop/ntopng
# 406509                      envoyproxy/envoy
# 510499              unicef/un-partner-portal
# 281118                      argoproj/argo-cd
# 527287                 SamuraiWTF/samuraiwtf
# 513413                 Kittyfisto/Tailviewer
# 58874               camptocamp/pyramid_oereb
# 137109        lucasmedeirosleite/EasyMapping
# 27640                      aspnet/AspNetCore
# 100841                         mochajs/mocha
# 423124                 uracreative/identihub
#
#                                                                                                        title  \
# 327903                                              after migration+checkout page blank only logo is showing
# 427704                                                         undefined references after building on ubuntu
# 115036                                                                                 network path creation
# 434724         typeahead: \ keydown\  events for enter and arrow keys should be ignored while \ composition\
# 221239                                utiliser cac120sv01 pour la fin anormale lors de l'appel à \ demarrer\
# 148646                                                                 невозможно обновить статус теста в бд
# 185244                                                      phpmyadmin  search  size large database not work
# 547590                                                                        adapt to new cruncher versions
# 208210                                                                         use with pact-consumer-js-dsl
# 87969                                             figure out how to convert a generic collection to an array
# 217696                   out of range tempos fail without programmer error notification when creating pieces
# 257242                            some weird error with regression test  pdkind/example9.mcmt  in debug mode
# 412095                                                          okno kondycji nie widzi osob czarnoodzianych
# 323566                                                                         intune configurator error 255
# 296801                                                               symbolkind.function returned for method
# 102211                                      enhancement: tns create <project> --template <xyz> has issues...
# 306101                                                     standalonesetup  unnecessary trailing whitespaces
# 163099                                                                           hackerone.com uses markdown
# 541134                                             \ method removeattribute does not have an implementation\
# 548750                                                       gracefully handle pre-skull-stripped t1w images
# 379336                                                      retryexponentialbackoff on a mono returns a flux
# 209486                                                                                    simple bmap parser
# 431518                                                                      redirect users already logged in
# 456179                                                                use semantic versioning where possible
# 117510                                                                       language settings page is empty
# 336778                                              better error when tools.namespace cannot find namespaces
# 401323                                           poison blob queue message in multi storage account scenario
# 437198                                                         time_delta issue in astropy.time's utc format
# 66574                                                    importing using es6 but jquery is loaded externally
# 334921                                                            shortcuts only work after opening settings
# ...                                                                                                      ...
# 251430                                                                         issue in try-it functionality
# 42219                                                                                db  - update er diagram
# 195325                                                                         remove asset pipeline support
# 278386                                                выполнение только одной строки в структуре сценария уф
# 264846                                                                          vhost panel does not show up
# 508800                                                  always add new attributes at the right of the table.
# 47904                                                                            links don't work in preview
# 307034                                                                    urls shouldn't have   or   in them
# 451674                                                                  problem with integrating semantic ui
# 424089                                                                           wcdb.swift pod update error
# 210028                                                       tail plugin with parser has incorrect timestamp
# 323022                                                                       is there acpi support in 86box?
# 272031                                                                  disabling loading specific packages?
# 305158                                                                    parallel pipeline + tinydb backend
# 87839                                                          don't display partitioned sums multiple times
# 13738                              display limits in inspector should be displayed in sensible scaled format
# 495916                                                                     incorrect order date in dashboard
# 228208                                                                         rename bounds_checked pragma?
# 227098                                                                mobile: site not quite mobile friendly
# 594966                                              assigning custom protocols to specific custom catagories
# 406509                                                               shasum not found when building on linux
# 510499                                                                             add scroll buttons to tab
# 281118                                                                 appprojectspec sourcerepos mislabeled
# 527287                                                               dvwa is missing from the bookmarks file
# 513413                                                    improve performance of log files without timestamp
# 58874                                                                       about all the rounding of values
# 137109                                       crash in version 0.20.0: collectentitynamesrecursively:mapping:
# 27640                                     consider adding a way to use strict comparison for routes matching
# 100841  \ commander.opts\  function gets overwritten with string \ test/mocha.opts\  in grunt-mocha-istanbul
# 423124                                       user receives an inaccurate notification upon e-mail activation
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            body  \
# 327903                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            i've migrated from m1.9.3.4 to m2.1.8 but when i goto checkout page after adding product to cart  it's shows empty page, only logo is showing.\r \r while other pages are fine.\r \r screenshots :- \r \r ! checkout-page-empty  https://user-images.githubusercontent.com/13333191/40978738-9ecee77a-68f1-11e8-82fe-23314e1b9648.png \r \r thanks!!!\r \r \r
# 427704  i had opencv version 2.4.12 running fine on my computer. i then built and installed version 3.1.0. now when i compile, i get\r    \r /tmp/ccjxy4xg.o: in function  cvpointfrom32f':\r /usr/local/include/opencv2/core/types_c.h:929: undefined reference to  cvround'\r /usr/local/include/opencv2/core/types_c.h:930: undefined reference to  cvround'\r /tmp/ccjxy4xg.o: in function  cvreadint':\r /usr/local/include/opencv2/core/core_c.h:2318: undefined reference to  cvround'\r /tmp/ccjxy4xg.o: in function  cvellipsebox':\r /usr/local/include/opencv2/imgproc/imgproc_c.h:1041: undefined reference to  cvround'\r /usr/local/include/opencv2/imgproc/imgproc_c.h:1042: undefined reference to  cvround'\r collect2: error: ld returned 1 exit status\r    \r \r i am compiling the following code.c file:\r    \r  include \ opencv2/highgui/highgui_c.h\ \r  include <stdio.h>\r int main int argc, char  argv   \r {\r       return 0;\r }\r    \r i am compiling it using \r    \r gcc -ggdb  pkg-config opencv --cf...
# 115036  the following is the proposed method for creating, storing and making ordered continuous paths available to the lrs database.\r \r   1. run the \ walk_network\  function to produce a tree  root to leaves  type structure.  \r \r   for now, focus on the main carriageway.\r \r   2. find all the leaves  endpoints of all branches .  \r   unnest these paths into their individual sections in a new table, along with a newly assigned \ path number\ .\r    \r insert into client.path_master\r \t fid_trail, fid_last \r \t select fid_trail, gid \r \tfrom client.network_walk \r \twhere gid \r \tnot in\r \t\t select unnest fid_trail 0:array_length fid_trail,1 -1   \r \t\tfrom client.network_walk\r \t\t \r \t ;\r    \r ! image  https://user-images.githubusercontent.com/24847630/35582100-aa3450ba-05e5-11e8-84b0-5a485d1c4a78.png \r \r   3. show these paths in qgis, this informs the user what has been done automatically.  \r \r <img src=\ https://user-images.githubusercontent.com/24847630/35584915-5b...
# 434724  first, i describe what is the \ composition\ .\r \r in cjk language regions, people use some software named \ im\   input method  to input heir local language text. for example, when i search a japanese term \ 日本語\   means \ japanese language\   in a zulip instance with firefox, i need to do:\r \r  1. click the search field.\r  2. activate the im. the \ composition\  session starts.\r  3. type keys:  n ,  i ,  h ,  o , and  n .  in a composition session \r  4. hit the space key to convert the text to japanese term. \ 日本\  is suggested.  in a composition session \r  5. hit the enter key to determine the text \ 日本\ .  in a composition session \r  6. type keys:  g , and  o .  in a composition session \r  7. hit the space key to convert the text to japanese term. \ 語\  is suggested.  in a composition session \r  8. hit the enter key to determine the text \ 語\ .  in a composition session \r  9. deactivate the im. the \ composition\  session ends.\r  10. hit the enter key again to search...
# 221239                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     appel à cac120sv01 au lieu du direct
# 148646                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          когда из контроллера пытаемся обратиться к сервису для изменения статуса теста, все ломается. вылетает исключение invaliddataaccessapiusageexception. аналогично при попытке удаления  да, я знаю, что мы не удаляем тесты совсем, но в контроллерах пока что по-старому. тоже надо пофиксить .
# 185244                                                                                                                                                                                                                                                                                                                                                                                                                                                                       steps to reproduce\r 1.table data length 1.89 gb  2,025,848,832 \r 2.search only the table\r 3.not found\r \r     expected behaviour\r search not found\r \r     actual behaviour\r found the search result\r \r     server configuration\r   operating system  :\r centos release 4.3  final \r   web server:  \r nginx 1.4.4\r   database:  \r 5.6.34\r   php version:  \r 5.5.99-hiphop\r   phpmyadmin version:  \r version information: 4.7.1\r     client configuration\r   browser:  \r chrome 58.0.3029.110  64-bit \r \r   operating system:  \r windows 7
# 547590                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              with the new api, the cruncher requirements will change significantly. in the medium term, it's expected that the cruncher will need to be adapted to better fit the api needs, and vice-versa:\r \r https://github.com/gfdrr/osm-analytics-cruncher/issues/7\r https://github.com/gfdrr/osm-analytics-cruncher/issues/8\r https://github.com/gfdrr/osm-analytics-cruncher/issues/9\r \r this discussion serves to help us identify which other ways the api can improve, and how that affects the cruncher
# 208210                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           as i understand those 2 libraries use the same pact-specification v.2.0.  so the question is:  can i use the mock and provider infrastructure from this library   pact-jvm   but use the consumer code from    pact-consumer-js-dsl    https://github.com/dius/pact-consumer-js-dsl  ?  sorry if the question is not supposed to be put there.
# 87969                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       not sure this is possible or doable:\r \r    java\r     public static <v> v   asarray final collection<v> tocopy  {\r         integrityutil.ensure tocopy, 0, \ must have a collection\  ;\r \r         final v   retval =  v    array.ensurecollection tocopy.get, tocopy.size   ;\r         \r         getlogger  .log level.fine, \ creating a copy of {0}\ , tocopy ;\r \r         retval.addall tocopy ;\r \r         return retval;\r     }\r
# 217696                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              initialise an ahafixedtempo with a tempo of 150000, then try to hand this to ahadroppiecedata as the tempo.  the ahadroppiecedata comes back nil without warning or error.  maybe invalid tempos should throw an exception?
# 257242  i know travis was able to run all the tests successfully in debug mode  https://travis-ci.org/sri-csl/sally/jobs/298145318 . however, when i run the command  sally  --engine=pdkind test/regress/pdkind/example9.mcmt  and built sally  master branch  in debug mode i get the following assertion violation:\r \r  assertion failed:  arithvar_has_right_type ctx, x, tau  , function translate_arithvar_to_eterm, file context/context.c, line 117. \r \r this is the output of  cmake .. \r \r    -- the cxx compiler identification is appleclang 7.3.0.7030031\r -- the c compiler identification is appleclang 7.3.0.7030031\r -- check for working cxx compiler: /usr/bin/c++\r -- check for working cxx compiler: /usr/bin/c++ -- works\r -- detecting cxx compiler abi info\r -- detecting cxx compiler abi info - done\r -- detecting cxx compile features\r -- detecting cxx compile features - done\r -- check for working c compiler: /usr/bin/cc\r -- check for working c compiler: /usr/bin/cc -- works\r -- detecti...
# 412095                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         aktywne okno kondycji nie dziala na osoby czarnoodziane,\r nie da sie klikac w nim zaatakowac/ wskazac/ czy cokolwiek innego jakby nie bylo ich na lokacji.\r \r \r  1/6  czarnoodziany rycerz chaosu ledwo muska xxx olbrzymim obosiecznym mieczem dwurecznym, \r trafiajac go w korpus.\r czarnoodziany rycerz chaosu jest ciezko ranny.\r nie widzisz zadnej takiej osoby.\r  wskaz   na  kogo / co   jako co  ?\r  rozkaz  komu   co .\r  \r
# 323566                                                                                                                                                                                                                                                                                                                                                                                                                                                              i am getting the following error when attempting to build/archive my ios project in non-debug mode:\r \r  /users/ryan/.nuget/packages/microsoft.intune.mam.xamarin.ios/8.1.1/build/xamarinios10/microsoft.intune.mam.xamarin.ios.targets 5,5 : error msb3073: the command \ /users/ryan/.nuget/packages/microsoft.intune.mam.xamarin.ios/8.1.1/build/xamarinios10/intunemamconfigurator -i info.plist -e \  exited with code 255.  msb3073   kobol.ios  \r \r i am not able to find any documentation on what exit code 255 is. any help here would be greatly appreciated.
# 296801                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           the method documentsymbolhandler mapkind   returns \ symbolkind.function\  when for a java method.\r my expectation is that it would return symbolkind.method.
# 102211                                                                                                                                                                                                                          since i make a bazillion plugins, i created a really cool template that automates a lot of the grunt work, however when you do a  tns create --template <plugintemplate>  - tns totally messes up my all new tns plugin project and really destroys it's usability.    \r \r can we make it so that if i have a flag in the template package.json like {\ cleantemplate\ : \ true\ } that the tns will not start messing with things it doesn't understand.  ;-    or if you must install all that crap; please put it into the \ demo\  folder  if the demo folder exists in the template ; as that is where the actual demo project will resides.   i have no problem automating the install of the demo folder; but man it is a serious pita to work around tns's attempt to destroy my cool new plugin...\r
# 306101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       the mwe2 workflow generates unnecessary trailing whitespaces into the <mydsl>standalonesetup.java file.\r \r ! standalonesetup_trailing_white_spaces  https://cloud.githubusercontent.com/assets/20393472/20090635/ad1a616a-a58e-11e6-8fbc-402ff9376607.png \r \r xtext-core/org.eclipse.xtext.xtext.generator/src/org/eclipse/xtext/xtext/generator/xtextgeneratortemplates.xtend
# 163099                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           needs to be added to the list.
# 541134  after trying to follow the getting started guide for more than an hour i still cannot get even the simplest possible wpf app to work with xamlcss.\r \r i have created a brand new wpf app, installed xamlcss.wpf 2.0.1 and all its dependencies and placed a button on the main window. then, no matter how i try to set the stylesheet of the window the app will not start due to an exception.\r \r methods i have tried:\r - calling  css.setstylesheet this, cssparser.parse \ button { ... }\   ;  in c  from the main window constructor.\r - adding  css:css.stylesheet=\ {dynamicresource stylesheet}\   to the window element in xaml  where  stylesheet  is set in window.resources .\r \r  i can see the exception and stack trace in the designer when using the xaml method, and it appears to be a    notimplementedexception   .\r \r i am calling  css.initialize  ;  in the main window constructor.\r \r     exception\r > typeloadexception: method 'removeattribute' in type 'xamlcss.wpf.dom.logicaldomelemen...
# 548750                                                                                                                                                                                                                                                                                                                                                                            a number of subjects in ds000223  e.g.  sub-07  https://s3.amazonaws.com/openneuro/ds000223/ds000223_r1.0.0/uncompressed/derivatives/mriqc/sub-07_t1w.html   have pre-skull-stripped t1w images. ants skull-stripping on these datasets clips most superficial cortex, resulting in very poor preprocessing.\r \r i propose adding a  --pre-skull-stripped  flag  or similar  to indicate that the anatomical workflow should assume the incoming image is already skull-stripped.\r \r alternately, we could do a test for a given percentage of zero voxels as evidence for skull-stripping, though this would need to be tested against defacers, as well.
# 379336                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      example: https://github.com/bjartek/webflux-retry/blob/master/src/main/kotlin/org/bjartek/webfluxretry/webfluxretryapplication.kt\r \r should it not return a mono?
# 209486                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    i've no idea if it's useful or not, but to get a handle on how bmap files work, i recently wrote a from-scratch parser which is kind of like a minimal implementation of  bmaptool copy .  it only uses modules from the python stdlib, nothing from bmap-tools \r https://gist.github.com/lurch/029674351674daa45511dba0d842fe4a\r \r if it's useful, feel free to include it in your repo; if it's not useful feel free to close this issue :slightly_smiling_face:
# 431518                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     if i am already logged-in, and access again the login page: http://localhost:8000/p/login, i should be redirected to the homepage.\r \r current behaviour: i stay on the login page, with the message _connecté_ affiché.\r \r \r ! loggedin  https://cloud.githubusercontent.com/assets/212768/14722999/bda0259c-07dc-11e6-9481-2c4c938000cd.png \r
# 456179                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      we should be using semantic versioning for the overall version number of the software in addition to each 'sub-project'  e.g. sync, services, etc... .  drupal modules will remain in the drupal versioning scheme.
# 117510                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     <a href=\ https://github.com/essensx\ ><img src=\ https://avatars1.githubusercontent.com/u/6651024?v=4\  align=\ left\  width=\ 96\  height=\ 96\  hspace=\ 10\ ></img></a>   issue by  essensx  https://github.com/essensx    _thursday dec 17, 2015 at 09:09 gmt_ _originally opened as https://github.com/qtranslate-team/qtranslate-x/issues/330_  ----  console reports there is an issue with uniqueid. jquery ... .uniqueid is not a function
# 336778                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              this happens for instance when  :omit-sources true  has been used when creating an uberjar.
# 401323                                                                                                                                                                                                                                                                                                                                                                                                                                                                               hi, i have setup two storage accounts in the connectionstrings. first one is setup as  azurewebjobsstorage  and a second as  azurewebjobsmytoken .  in the second account a blob trigger is configured via an attribute on the class   storageaccount \ mytoken\    . in case this blob trigger fails multiple times a poison blob message is generated in the queue  webjobs-blobtrigger-poison  of the first storage account. my expectation was that the same storage account, as used for the trigger, is used for the poison message.  thanks, fabian
# 437198  i was using time delta for generating utcs for an entire year at an interval of 12 hours.\r \r time_start = time  str year + '-01-01 00:00:00', scale='utc' \r time_start_plus_one_second = time  str year + '-01-01 00:00:01', scale='utc' \r time_start_plus_24_hours = time  str year + '-01-02 00:00:00', scale='utc' \r \r  time_difference\r one_second = time_start_plus_one_second - time_start\r one_day = time_start_plus_24_hours - time_start\r \r for day in range 0,days,1 :\r         for i in range 0,24x60x60,step :\r \r             time = time_start +  one_second i  +  one_day day \r             print  time \r \r for year 2015 the output i got is fine until i reach july 1:\r \r 2015-06-29 00:00:00.000\r 2015-06-29 12:00:00.000\r 2015-06-30 00:00:00.000\r 2015-06-30 12:00:00.000\r 2015-06-30 23:59:60.000\r 2015-07-01 11:59:59.000\r 2015-07-01 23:59:59.000\r 2015-07-02 11:59:59.000\r 2015-07-02 23:59:59.000\r 2015-07-03 11:59:59.000\r \r similar is the output for year 2012. \r \r but if...
# 66574                                                                                                                                                                                                                                                                                                                                                                            ok so my situation is a bit sticky. i am developing a wordpress theme for a client, but i am using es6 with babel and browserify for my custom code. problem is i cant just deregister jquery because the majority of wp plugins require it.\r so in every es6 module i just  const $ = window.jquery   because i just couldn't make browserify shim to work properly . \r but now when i  import 'jquery-circle-progress'  i jsut get that circleprogress is not a function of jquery. any suggestions how i should proceed ? \r at this point i just added the whole plugin into my libraries js stack, and its available everywhere, but that's not cool.\r
# 334921                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             tested on windows with both 0.6 and the latest development build  0.7-4699-0f5dab6 . both keyboard and gamepad shortcuts will only work after the settings window was opened. don't even have to close it or click ok/apply.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# ...
# 227098           1
# 594966           1
# 406509           1
# 510499           2
# 281118           2
# 527287           1
# 513413           1
# 58874            1
# 137109           2
# 27640            2
# 100841           2
# 423124           1
#
#                                                                                                                                                       labels  \
# 327903                                                                                                                                          ["question"]
# 427704                                                                                                               ["category: build/install", "question"]
# 115036                                                                                                 ["help wanted", "idea", "implementation", "question"]
# 434724                                                                           ["area: i18n", "area: keyboard UI", "bug", "in progress", "priority: high"]
# 221239                                                                                                                                        ["bug", "bug"]
# 148646                                                                                                                                               ["bug"]
# 185244                                                                                                                                          ["question"]
# 547590                                                                                                                                        ["discussion"]
# 208210                                                                                                                                       ["enhancement"]
# 87969                                                                                                                                        ["enhancement"]
# 217696                                                                                                                        ["enhancement", "enhancement"]
# 257242                                                                                                                              ["question", "question"]
# 412095                                                                                                                                       ["enhancement"]
# 323566                                                                                                  ["assigned-to-author", "support-request", "triaged"]
# 296801                                                                                                                                               ["bug"]
# 102211                                                                                                                                          ["question"]
# 306101                                                                                                                                  ["bug", "confirmed"]
# 163099                                                                                                                        ["enhancement", "enhancement"]
# 541134                                                                                                                                          ["question"]
# 548750                                                                                                                                ["bug", "refactoring"]
# 379336                                                                                                                   ["enhancement", "good first issue"]
# 209486                                                                                                                                          ["question"]
# 431518                                                                                                                        ["feature", "python", "ready"]
# 456179                                                                                                          ["documentation", "help wanted", "question"]
# 117510                                                                                                                             ["enhancement", "import"]
# 336778                                                                                                                        ["enhancement", "enhancement"]
# 401323                                                                                                                             ["bug", "rc:should-have"]
# 437198                                                                                                                        ["Close?", "question", "time"]
# 66574                                                                                                                                                ["bug"]
# 334921                                                                                                                  ["category:questionable", "port:Qt"]
# ...                                                                                                                                                      ...
# 251430                                                                                                                                ["bug", "major", "v3"]
# 42219                                                                                                                                          ["bug", "DB"]
# 195325                                                                                                                            ["0. Needs triage", "bug"]
# 278386                                                                                                                                       ["enhancement"]
# 264846                                                                                                                                          ["question"]
# 508800                                                                                                                        ["enhancement", "enhancement"]
# 47904                                                                                                                                        ["enhancement"]
# 307034                                                                                                                                               ["bug"]
# 451674                                                                                                                                          ["question"]
# 424089                                                                                                                    ["iOS/macOS", "question", "stale"]
# 210028                                                                                                               ["enhancement", "fixed", "Implemented"]
# 323022                                                                                                                                          ["question"]
# 272031                                                                                                                                          ["question"]
# 305158                                                                                                                                               ["bug"]
# 87839                                                                                                                                      ["bug", "urgent"]
# 13738   ["f - inspector", "level - easy", "p2 - high", "type - bug", "w4 - ready", "f - inspector", "level - easy", "p2 - high", "type - bug", "w4 - ready"]
# 495916                                                                                                                        ["question", "support center"]
# 228208                                                                                                                             ["work item", "question"]
# 227098                                                                                                                                               ["bug"]
# 594966                                                                                                                                          ["question"]
# 406509                                                                                                                                          ["question"]
# 510499                                                                                                                                  ["bug", "delivered"]
# 281118                                                                                                                                         ["P1", "bug"]
# 527287                                                                                                                                       ["enhancement"]
# 513413                                                                                                                                               ["bug"]
# 58874                                                                                                                               ["question", "question"]
# 137109                                                                                                                     ["awaiting feedback", "question"]
# 27640                                                                                                                        ["enhancement", "repo:Routing"]
# 100841                                                                                                                                 ["question", "stale"]
# 423124                                                                                                                                       ["enhancement"]
#
#         num_concurrent_classes  c_bug  c_feature  c_question  c_other  \
# 327903                       1  False      False        True    False
# 427704                       1  False      False        True    False
# 115036                       1  False      False        True    False
# 434724                       1   True      False       False    False
# 221239                       1   True      False       False    False
# 148646                       1   True      False       False    False
# 185244                       1  False      False        True    False
# 547590                       1  False      False        True    False
# 208210                       1  False       True       False    False
# 87969                        1  False       True       False    False
# 217696                       1  False       True       False    False
# 257242                       1  False      False        True    False
# 412095                       1  False       True       False    False
# 323566                       1  False       True       False    False
# 296801                       1   True      False       False    False
# 102211                       1  False      False        True    False
# 306101                       1   True      False       False    False
# 163099                       1  False       True       False    False
# 541134                       1  False      False        True    False
# 548750                       1   True      False       False    False
# 379336                       1  False       True       False    False
# 209486                       1  False      False        True    False
# 431518                       1  False       True       False    False
# 456179                       1  False      False        True    False
# 117510                       1  False       True       False    False
# 336778                       1  False       True       False    False
# 401323                       1   True      False       False    False
# 437198                       1  False      False        True    False
# 66574                        1   True      False       False    False
# 334921                       1  False      False        True    False
# ...                        ...    ...        ...         ...      ...
# 251430                       1   True      False       False    False
# 42219                        1   True      False       False    False
# 195325                       1   True      False       False    False
# 278386                       1  False       True       False    False
# 264846                       1  False      False        True    False
# 508800                       1  False       True       False    False
# 47904                        1  False       True       False    False
# 307034                       1   True      False       False    False
# 451674                       1  False      False        True    False
# 424089                       1  False      False        True    False
# 210028                       1  False       True       False    False
# 323022                       1  False      False        True    False
# 272031                       1  False      False        True    False
# 305158                       1   True      False       False    False
# 87839                        1   True      False       False    False
# 13738                        1   True      False       False    False
# 495916                       1  False      False        True    False
# 228208                       1  False      False        True    False
# 227098                       1   True      False       False    False
# 594966                       1  False      False        True    False
# 406509                       1  False      False        True    False
# 510499                       1   True      False       False    False
# 281118                       1   True      False       False    False
# 527287                       1  False       True       False    False
# 513413                       1   True      False       False    False
# 58874                        1  False      False        True    False
# 137109                       1  False      False        True    False
# 27640                        1  False       True       False    False
# 100841                       1  False      False        True    False
# 423124                       1  False       True       False    False
#
#        prediction
# 327903        bug
# 427704        bug
# 115036    feature
# 434724    feature
# 221239    feature
# 148646    feature
# 185244        bug
# 547590    feature
# 208210   question
# 87969    question
# 217696        bug
# 257242        bug
# 412095        bug
# 323566        bug
# 296801    feature
# 102211    feature
# 306101    feature
# 163099        bug
# 541134        bug
# 548750    feature
# 379336        bug
# 209486    feature
# 431518        bug
# 456179    feature
# 117510        bug
# 336778        bug
# 401323   question
# 437198        bug
# 66574    question
# 334921        bug
# ...           ...
# 251430   question
# 42219     feature
# 195325    feature
# 278386        bug
# 264846        bug
# 508800        bug
# 47904         bug
# 307034    feature
# 451674        bug
# 424089        bug
# 210028        bug
# 323022    feature
# 272031        bug
# 305158    feature
# 87839     feature
# 13738     feature
# 495916        bug
# 228208    feature
# 227098    feature
# 594966    feature
# 406509        bug
# 510499    feature
# 281118    feature
# 527287        bug
# 513413    feature
# 58874     feature
# 137109        bug
# 27640    question
# 100841        bug
# 423124        bug
#
# [85041 rows x 12 columns]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.hist(preds[:, 0][y_pred == 0])
# Out:
# (array([  586.,  2331.,  8821., 10839., 11815., 13705., 17155., 23454.,
#         38482., 86098.]),
#  array([0.34, 0.4 , 0.47, 0.54, 0.6 , 0.67, 0.74, 0.8 , 0.87, 0.93, 1.  ],
#        dtype=float32),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Try DR

# %%
testdf = pd.read_pickle('testdf.pkl')
testdf['partition'] = 'test'

traindf = pd.read_pickle('traindf.pkl')
traindf['partition'] = 'train'

# %%
original_data = pd.concat([traindf, testdf])
original_data = original_data[~original_data.c_other]

# %%
def collapse_label(x):
    if x.c_bug:
        return 'bug'
    elif x.c_feature:
        return 'feature'
    
    return 'question'

# %%
original_data['class_label'] = original_data.apply(lambda x: collapse_label(x), axis=1)

# %%
original_data.head()
# Out:
#                                                                      url  \
# 68065                        "https://github.com/ESMCI/cime/issues/2435"
# 75697   "https://github.com/prescottprue/react-redux-firebase/issues/51"
# 256798                     "https://github.com/PX4/Firmware/issues/8148"
# 189228      "https://github.com/Tizra/Tizra-Customer-Tracker/issues/460"
# 1108                          "https://github.com/agda/agda/issues/2431"
#
#                                      repo  \
# 68065                          ESMCI/cime
# 75697   prescottprue/react-redux-firebase
# 256798                       PX4/Firmware
# 189228       Tizra/Tizra-Customer-Tracker
# 1108                            agda/agda
#
#                                                                                     title  \
# 68065                                can we stop copying log files to the case directory?
# 75697   isloaded helper always returns false when a default value is supplied to datatojs
# 256798                              reboot via qgc does not restore dropped rc connection
# 189228                                                  unpublish doesn't work from lists
# 1108                                         making the uhc backend a stand-alone product
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            body  \
# 68065                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            i was talking to @cecilehannay about disk space issues on cheyenne. she pointed out that it's often useful to keep case directories around for a long time, but they take up much more space than they need to because the log files are copied into your case directory. can we stop copying log files into your case directory, just leaving them in your archive directory?
# 75697                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    if you provide a default value to  datatojs  the  isloaded  helper always returns true, meaning loading spinners cannot be displayed.\r \r minimal working example from the  yo  generator: https://github.com/will-hart/react-redux-firebase-mwe\r \r all the action is in here https://github.com/will-hart/react-redux-firebase-mwe/tree/master/src/routes/home\r \r database looks like this:\r \r ! image  https://cloud.githubusercontent.com/assets/391950/22526729/79c71ca6-e920-11e6-88a8-71999bee4d33.png \r
# 256798                                                                                                                                                                                                                                                                                quite often i have the rc control stop working after powering on the autopilot.  it doesn't lose signal or indicate lost connection in qgc, it just stops responding to inputs from the rc radio. this only happens before arming, never after. it seems to not happen if i constantly move the sticks pretty regularly, but if left alone for a minute.\r \r i'm not sure why this happens, but at the least if i could reboot via qgc and restore control that would be fine. that doesn't work however, so i have to open a hatch and physically unplug the power. is there a known reason why the autopilot stops responding to input? if it's a big process to fix the issue, is there a way to restore it via software reboot for the short term?\r
# 189228                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               when i try to unpublish items by checking them off on a list then clicking unpublish nothing happens.  delete and publish operations seem to be ok.\r \r tested on collections, documents, excerpts and static pages.\r \r
# 1108    i've put together an api for compiler backends for some students of mine. this makes it easy to write backends using agda as a library. basically you implement a few callbacks in a  backend  type and then define\r \r    haskell\r main = runagda  mybackend \r    \r \r this gets you a fully functional agda executable with your backend included.\r \r i've successfully migrated the ghc and uhc backends to use this api. now, i would like to exploit this to separate the uhc backend from the agda code base. as far as i see things, there is a strong case for doing this:\r \r - uhc is an research compiler which not heavily maintained.\r - as far as i know, no one is relying on the uhc backend.\r - the uhc backend is costing us a non-trivial bit of maintenance work.\r - a separate uhc backend can still be maintained in its own repo, but it would only need to be updated for every new release, instead of every time something changes that affects the backends.\r \r anyway, i thought i'd check i...
#
#         num_labels  \
# 68065            3
# 75697            1
# 256798           2
# 189228           2
# 1108             3
#
#                                                                             labels  \
# 68065                            ["in progress", "tp: CIMElib", "ty: enhancement"]
# 75697                                                              ["enhancement"]
# 256798                                                     ["bug", "status/STALE"]
# 189228                                                        ["bug", "duplicate"]
# 1108    ["discussion", "task", "uhc-backend", "discussion", "task", "uhc-backend"]
#
#         num_concurrent_classes  c_bug  c_feature  c_question  c_other  \
# 68065                        1  False       True       False    False
# 75697                        1  False       True       False    False
# 256798                       1   True      False       False    False
# 189228                       1   True      False       False    False
# 1108                         1  False      False        True    False
#
#        partition class_label
# 68065      train     feature
# 75697      train     feature
# 256798     train         bug
# 189228     train         bug
# 1108       train    question

# %%
original_data[['repo', 'title', 'body', 'class_label', 'partition']].to_csv('issue_label_forDR.csv', index=False)

# %%
original_data.groupby('partition').count()
# Out:
#                url     repo    title     body  num_labels   labels  \
# partition
# test        476064   476064   476064   476064      476064   476064
# train      2699061  2699061  2699061  2699061     2699061  2699061
#
#            num_concurrent_classes    c_bug  c_feature  c_question  c_other  \
# partition
# test                       476064   476064     476064      476064   476064
# train                     2699061  2699061    2699061     2699061  2699061
#
#            class_label
# partition
# test            476064
# train          2699061
